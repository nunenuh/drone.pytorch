# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split



import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

from torchvision import transforms as T
import torchvision



from PIL import Image
import cv2
import albumentations as A

import time
import os
from tqdm.notebook import tqdm

from pathlib import Path

# %%
import tifffile as tiff
import cv2 as cv
mask_root = '/data/semantic_drone/training_set/gt/semantic/label_tiff/000.tiff'
img_root = '/data/semantic_drone/training_set/images/000.jpg'

# tiff.imsave('', masks, compress=1)
mask_img = tiff.imread(mask_root)
orig_img = Image.open(img_root)
orig_img = np.array(orig_img)
orig_img = cv.resize(orig_img, dsize=(mask_img.shape[1], mask_img.shape[0]), interpolation=cv.INTER_AREA)

# %%
mask_img.shape
# Out:
# (800, 1200, 24)

# %%
plt.figure(figsize=(12,12))
plt.imshow(orig_img)
plt.imshow(mask_img[:,:,1], alpha=0.5)
plt.show()
